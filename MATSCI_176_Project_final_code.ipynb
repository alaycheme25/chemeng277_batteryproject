# %% [markdown]
# ### Importing necessary packages and files

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from sklearn.decomposition import PCA
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans
from sklearn.model_selection import KFold, cross_val_score
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
import paretoset
import periodictable
from pymatgen.core import Structure
import ast
from sklearn.linear_model import ElasticNet
from xgboost import XGBRegressor

# %%
# Importing train and test data
pdata = pd.read_excel("MATSCI_176_Project_Data.xlsx")
test_data = pd.read_csv("mp_battery_test_data.csv")
pdata.head()
# Out:
#   battery_formula working_ion elements  nelements formula_charge  \
# 0         Li0-3Ag          Li   ['Ag']        1.0             Ag
# 1         Li0-3Sb          Li   ['Sb']        1.0             Sb
# 2         Li0-1Bi          Li   ['Bi']        1.0             Bi
# 3         Li0-3Ce          Li   ['Ce']        1.0             Ce
# 4         Li0-3Ca          Li   ['Ca']        1.0             Ca
#
#   formula_discharge  max_delta_volume  average_voltage  capacity_grav  \
# 0             Li3Ag          2.736089         0.210565     624.785871
# 1             Li3Sb          1.569237         1.015953     563.913254
# 2              LiBi          0.368255         0.796796     124.126099
# 3             Li3Ce          2.951183        -0.444846     499.595769
# 4             Li3Ca          1.513956        -0.064931    1320.248328
#
#    capacity_vol  ...   energy_vol  stability_charge  stability_discharge  \
# 0   1984.816229  ...   417.933696          0.003609             0.000000
# 1   1890.293779  ...  1920.448911          0.328351             0.000000
# 2    923.538664  ...   735.871648          0.049545             0.000000
# 3   1295.168213  ...  -576.149771          0.000000             0.333634
# 4   1271.741142  ...   -82.574983          0.000000             0.057445
#
#    electrode_density  material_density battery_workingion_cost_per_kWh  \
# 0           3.176794          2.592432                           108.0
# 1           3.352100          3.378028                           108.0
# 2           7.440326          2.237712                           108.0
# 3           2.592432          2.583328                           108.0
# 4           0.963259          7.527518                           108.0
#
#                                            structure  \
# 0  {'@module': 'pymatgen.core.structure', '@class...
# 1  {'@module': 'pymatgen.core.structure', '@class...
# 2  {'@module': 'pymatgen.core.structure', '@class...
# 3  {'@module': 'pymatgen.core.structure', '@class...
# 4  {'@module': 'pymatgen.core.structure', '@class...
#
#   formation_energy_per_atom band_gap energy_density
# 0                  0.333634        0     417.933696
# 1                 -0.744135   0.7074    1920.448911
# 2                 -0.034716        0     735.871648
# 3                 -0.330999        0     576.149771
# 4                 -0.415156        0      82.574983
#
# [5 rows x 21 columns]

# %% [markdown]
# Extracting Lattice Parameters

# %%
structures = pdata["structure"]
print(structures.shape)
structure_dict_test = ast.literal_eval(structures[1])
structure_test = Structure.from_dict(structure_dict_test)
print(structure_test)
print(structure_test.lattice.abc)
print(structure_test.volume)
# Out:
# (5786,)
# Full Formula (Li3 Sb1)
# Reduced Formula: Li3Sb
# abc   :   4.627959   4.627959   4.627959
# angles:  60.000007  60.000010  60.000007
# pbc   :       True       True       True
# Sites (4)
#   #  SP       a      b     c    magmom
# ---  ----  ----  -----  ----  --------
#   0  Li    0.5    0.5   0.5          0
#   1  Li    0.25   0.25  0.25        -0
#   2  Li    0.75   0.75  0.75        -0
#   3  Sb    0     -0     0            0
# (4.627959209506349, 4.627958733729667, 4.62795882)
# 70.08959778250679

# %%
# Obtaining structure volume (was removed from feature list in final iterations)
# def get_volume(structure_str):
#     try:
#         structure_dict = ast.literal_eval(structure_str)
#         structure = Structure.from_dict(structure_dict)
#         return structure.volume
#     except:
#         return np.nan
# structure_volums = pdata["structure"].apply(get_volume) # Volumes in Angstrom^3

# Define function to get lattice parameters
def get_abc(structure_str):
    try:
        structure_dict = ast.literal_eval(structure_str)
        structure = Structure.from_dict(structure_dict)
        return structure.lattice.abc
    except:
        return np.nan
structure_abc = pdata["structure"].apply(get_abc) # abc values in Angstrom
structure_abc_df = pd.DataFrame(structure_abc.tolist(), columns=['a', 'b', 'c'])
pdata = pdata.drop(columns=["structure"], axis=1)
pdata = pd.concat([pdata, structure_abc_df], axis=1)

# %%
# Convert all columns to float values and eliminate any rows with missing values
numeric_cols = [
    "material_density",
    "formation_energy_per_atom",
    "band_gap"
]

for col in numeric_cols:
    pdata[col] = pd.to_numeric(pdata[col], errors="coerce")
pdata = pdata.dropna()
pdata = pdata.reset_index(drop=True)
pdata_norm = pdata.iloc[:, 6:]

# %% [markdown]
# #### Defining our scoring function(s) to analyze and their input datasets.
# We use the gravimetric energy density (GED) as our predicted output. Hence, gravimetric and volumetric energy densities and corresponding values are removed from the train dataset. Volumetric capacity is also dropped as it was not available in our test data. The battery material costs were initially planned to be a screening factor, but were dropped from this project. It might be used in future iterations after including more features (namely, atomic contributions).

# %%
# Editing the train dataset
energy_grav = pdata_norm["energy_grav"]
cap_grav = pdata_norm["capacity_grav"]
energy_density = pdata_norm["energy_density"]
voltage = pdata_norm['average_voltage']
training_data = pdata_norm.drop(columns=["energy_grav", "energy_density", "electrode_density", "stability_charge", "energy_vol", "capacity_vol"])
training_data["average_voltage"] = np.abs(training_data["average_voltage"]) # absolute voltage of voltage is taken since the sign only indicates the type of electrode
training_data_nocost = training_data.drop(columns=["battery_workingion_cost_per_kWh"])

# %%
def scoring_nocost(e_g):
    e_g = e_g.to_numpy().astype(float)
    score = np.abs(e_g) # absolute value of GED is used as sign indicates type of electrode
    return pd.Series(score)

# %% [markdown]
# ### Benchmarking the Ridge & ElasticNet Regressional Models
# We chose Ridge regression and ElasticNet regression to both identify important features (from the ElasticNet's Lasso component) while zeroing out features which don't affect battery performance (features that don't affect our score.)

# %%
# Calling the no-cost scoring function and defining our fit & training datasets.
battery_score = scoring_nocost(energy_grav)

fit_train, fit_test, score_train, score_test = train_test_split(
    training_data_nocost,
    battery_score,
    test_size=0.1,
    random_state=42
)

# Normalization of the fit and training datasets for testing ridge without cross validation
norm_fit_train = pd.DataFrame(
    StandardScaler().fit_transform(fit_train),
    columns=fit_train.columns
)
norm_fit_test = pd.DataFrame(
    StandardScaler().fit_transform(fit_test),
    columns=fit_test.columns
)

# %%
# Ridge modelling without CV
ridge = linear_model.Ridge(alpha=3.0).fit(fit_train, score_train, sample_weight=None)
score_pred = ridge.score(fit_test, score_test)
print(f"Effective R^2 score: {score_pred:.3f}")
# Out:
# Effective R^2 score: 0.603

# %%
# Printing out the best predicted battery
best = np.where(battery_score == np.max(battery_score))[0][0]
print(pdata.iloc[best])
print("Battery Score:", np.max(battery_score))
# Out:
# battery_formula                       Li0-3ClO
# working_ion                                 Li
# elements                           ['Cl', 'O']
# nelements                                  2.0
# formula_charge                             ClO
# formula_discharge                       Li3ClO
# max_delta_volume                      1.020934
# average_voltage                       4.299346
# capacity_grav                      1112.473171
# capacity_vol                       2236.418805
# energy_grav                        4782.906878
# energy_vol                         9615.137841
# stability_charge                      1.553271
# stability_discharge                   0.027568
# electrode_density                     2.010313
# material_density                      3.455668
# battery_workingion_cost_per_kWh          108.0
# formation_energy_per_atom            -0.151988
# band_gap                                   0.0
# energy_density                     9615.137841
# a                                     4.677535
# b                                     4.677535
# c                                     4.677535
# Name: 4014, dtype: object
# Battery Score: 4782.9068783623

# %% [markdown]
# ## Performing K-folds cross validation on our ridge regressional model.
# Choosing k-folds is important to determine if our train-validation split was truely indicative of the full system.

# %%
X = training_data_nocost
y = battery_score
y = y.fillna(0)
y = y.astype(float)

# %%
ridge_pipeline = Pipeline([
    ("scaler", StandardScaler()), # Normalization
    ("ridge", linear_model.Ridge(alpha=3.0))
])

# %%
kf = KFold(n_splits=10, shuffle=True, random_state=42) # 10-fold CV

r2_scores = []
MAE = []
MSE = []
bestmaterial_ridge = []
params = []
best_ridge_score = []

for train_idx, test_idx in kf.split(X):

    X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
    y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]

    ridge_pipeline.fit(X_train, y_train)
    y_pred = ridge_pipeline.predict(X_test)
    params.append(ridge_pipeline.named_steps["ridge"].coef_)

    #Find best material in predicted set
    bestmaterial_ridge.append(X_test.iloc[np.where(y_pred == np.max(y_pred))[0][0]])
    best_ridge_score.append(np.max(y_pred))

    r2_scores.append(r2_score(y_test, y_pred))
    MSE.append(mean_squared_error(y_test, y_pred))
    MAE.append(mean_absolute_error(y_test, y_pred))

print("Mean R2:", np.mean(r2_scores))
print("Mean MSE:", np.mean(MSE))
print("Mean MAE:", np.mean(MAE))
bestmaterial_df_ridge = pd.DataFrame(bestmaterial_ridge)
# Out:
# Mean R2: 0.5621540601761627
# Mean MSE: 44804.44849372668
# Mean MAE: 127.01733771171118

# %%
# Converting the best material features back to the original scale for comparison with the original dataset, since we normalized the training & test data.
# To do so, we took the best material from each fold and compared their features to the original datasets to find the approximated battery  (the battery formula with the smallest minimum difference between predicted best and the rest of the dataset).
for i in range(len(bestmaterial_df_ridge)):
    best_material = bestmaterial_df_ridge.iloc[i]
    min_diff = float('inf')
    best_match_index = -1
    for j in range(len(pdata)):
        diff = np.sum(np.abs(best_material - pdata.iloc[j, 6:6+len(best_material)]))
        if diff < min_diff:
            min_diff = diff
            best_match_index = j
    print(f"Best material in fold {i+1}:")
    print(pdata.iloc[best_match_index, 0])
# Out:
# Best material in fold 1:
# Li0-1Cr2(PO4)3
# Best material in fold 2:
# Ca0.25-0.5C
# Best material in fold 3:
# Li0-0.25Fe2O3F
# Best material in fold 4:
# Li1-3Ti2(PO4)3
# Best material in fold 5:
# Mg7-149Cs
# Best material in fold 6:
# Mg7-149Cr
# Best material in fold 7:
# Mg0-1Eu6WO12
# Best material in fold 8:
# Na0-0.5CrO2
# Best material in fold 9:
# Li0-0.5CrO2
# Best material in fold 10:
# Mg7-149V

# %% [markdown]
# ## Performing K-folds cross validation on our ElasticNet Model

# %%
alpha = 3.25 # Hyperparameter was optimized for best test prediction, not train prediction
l1_ratio = 0.5 # 0=ridge-like, 1=lasso-like

enet_pipeline = Pipeline([
    ("enet", ElasticNet(alpha=alpha, l1_ratio=l1_ratio, max_iter=20000, random_state=42))
])

score_pred_enet = enet_pipeline.fit(fit_train, score_train).score(fit_test, score_test)
print("ElasticNet test R^2:", score_pred_enet)
# Out:
# ElasticNet test R^2: 0.5366851725714992

# %%
#replace Ridge KFold with Elastic Net KFold

X = training_data_nocost
y = battery_score.fillna(0).astype(float)

# Elastic Net hyperparameters
alpha = 3.25
l1_ratio = 0.5

enet_pipeline = Pipeline([
    ("scaler", StandardScaler()),
    ("enet", ElasticNet(alpha=alpha, l1_ratio=l1_ratio, max_iter=20000, random_state=42))
])

kf = KFold(n_splits=10, shuffle=True, random_state=42)

r2_scores = []
MAE = []
MSE = []
bestmaterial_elastic = []
best_elastic_score = []

for train_idx, test_idx in kf.split(X):
    X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
    y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]

    enet_pipeline.fit(X_train, y_train)
    y_pred = enet_pipeline.predict(X_test)
    bestmaterial_elastic.append(X_test.iloc[np.argmax(y_pred)])
    best_elastic_score.append(np.max(y_pred))

    r2_scores.append(r2_score(y_test, y_pred))
    MSE.append(mean_squared_error(y_test, y_pred))
    MAE.append(mean_absolute_error(y_test, y_pred))

print("Mean R^2:", np.mean(r2_scores))
print("Mean MSE:", np.mean(MSE))
print("Mean MAE:", np.mean(MAE))

bestmaterial_df_elastic = pd.DataFrame(bestmaterial_elastic)
# Out:
# Mean R^2: 0.3237995484818546
# Mean MSE: 69479.7008097721
# Mean MAE: 189.14459837633234

# %%
for i in range(len(bestmaterial_elastic)):
    best_material_temp = bestmaterial_df_elastic.iloc[i]
    min_diff = float('inf')
    best_match_index = -1
    for j in range(len(pdata)):
        diff = np.sum(np.abs(best_material_temp - pdata.iloc[j, 6:6+len(best_material_temp)]))
        if diff < min_diff:
            min_diff = diff
            best_match_index = j
    print(f"Best material in fold {i+1}:")
    print(pdata.iloc[best_match_index, 0])
# Out:
# Best material in fold 1:
# Mg1-149Bi
# Best material in fold 2:
# Ca0.25-0.5C
# Best material in fold 3:
# Li0-0.25Fe2O3F
# Best material in fold 4:
# Li1-3Ti2(PO4)3
# Best material in fold 5:
# Mg7-149Cs
# Best material in fold 6:
# Li0-1Mn4(P2O7)3
# Best material in fold 7:
# Mg0-1Eu6WO12
# Best material in fold 8:
# Na0-0.5CrO2
# Best material in fold 9:
# Li0-0.5CrO2
# Best material in fold 10:
# Li0-1Co(CO3)2

# %% [markdown]
# ## Defining and training the X-B boost model

# %%
x_model = XGBRegressor(n_estimators=1000, learning_rate=0.05) # Some tests were also done with other parameters including early_stopping_rounds to identify the best n_estimators/learning_rate balance and the given vaues were chosen
x_model.fit(fit_train, score_train, eval_set=[(fit_test, score_test)])
# Out:
# [0]	validation_0-rmse:286.71521
# [1]	validation_0-rmse:273.60485
# [2]	validation_0-rmse:259.73316
# [3]	validation_0-rmse:248.09385
# [4]	validation_0-rmse:236.72925
# [5]	validation_0-rmse:224.69781
# [6]	validation_0-rmse:214.29077
# [7]	validation_0-rmse:203.60366
# [8]	validation_0-rmse:194.03603
# [9]	validation_0-rmse:184.92657
# [10]	validation_0-rmse:176.70297
# [11]	validation_0-rmse:168.72669
# [12]	validation_0-rmse:161.20530
# [13]	validation_0-rmse:154.50607
# [14]	validation_0-rmse:147.90413
# [15]	validation_0-rmse:141.81225
# [16]	validation_0-rmse:136.10920
# [17]	validation_0-rmse:131.21454
# [18]	validation_0-rmse:126.42051
# [19]	validation_0-rmse:121.72428
# [20]	validation_0-rmse:117.72100
# [21]	validation_0-rmse:113.73297
# [22]	validation_0-rmse:110.36369
# [23]	validation_0-rmse:106.87868
# [24]	validation_0-rmse:103.67853
# [25]	validation_0-rmse:100.75438
# [26]	validation_0-rmse:98.01087
# [27]	validation_0-rmse:95.44815
# [28]	validation_0-rmse:93.19437
# [29]	validation_0-rmse:91.21089
# [30]	validation_0-rmse:89.63365
# [31]	validation_0-rmse:87.61322
# [32]	validation_0-rmse:85.86813
# [33]	validation_0-rmse:84.65032
# [34]	validation_0-rmse:83.72263
# [35]	validation_0-rmse:81.73280
# [36]	validation_0-rmse:80.99772
# [37]	validation_0-rmse:79.31344
# [38]	validation_0-rmse:78.99932
# [39]	validation_0-rmse:78.80108
# [40]	validation_0-rmse:78.52628
# [41]	validation_0-rmse:78.52693
# [42]	validation_0-rmse:78.57398
# [43]	validation_0-rmse:78.67689
# [44]	validation_0-rmse:78.49282
# [45]	validation_0-rmse:78.75993
# [46]	validation_0-rmse:79.09680
# [47]	validation_0-rmse:79.44578
# [48]	validation_0-rmse:79.82716
# [49]	validation_0-rmse:80.14962
# [50]	validation_0-rmse:80.59225
# [51]	validation_0-rmse:81.07544
# [52]	validation_0-rmse:81.55200
# [53]	validation_0-rmse:82.05867
# [54]	validation_0-rmse:82.56458
# [55]	validation_0-rmse:83.07567
# [56]	validation_0-rmse:83.59755
# [57]	validation_0-rmse:83.70619
# [58]	validation_0-rmse:84.28272
# [59]	validation_0-rmse:84.40888
# [60]	validation_0-rmse:84.38634
# [61]	validation_0-rmse:84.36145
# [62]	validation_0-rmse:84.91547
# [63]	validation_0-rmse:84.88794
# [64]	validation_0-rmse:85.43632
# [65]	validation_0-rmse:85.44462
# [66]	validation_0-rmse:85.44380
# [67]	validation_0-rmse:85.61507
# [68]	validation_0-rmse:85.70385
# [69]	validation_0-rmse:85.82656
# [70]	validation_0-rmse:85.94676
# [71]	validation_0-rmse:86.03158
# [72]	validation_0-rmse:86.05060
# [73]	validation_0-rmse:86.18599
# [74]	validation_0-rmse:86.32545
# [75]	validation_0-rmse:86.42686
# [76]	validation_0-rmse:86.52467
# [77]	validation_0-rmse:86.60506
# [78]	validation_0-rmse:86.60567
# [79]	validation_0-rmse:87.03315
# [80]	validation_0-rmse:87.03177
# [81]	validation_0-rmse:87.08346
# [82]	validation_0-rmse:87.50024
# [83]	validation_0-rmse:87.87979
# [84]	validation_0-rmse:87.92879
# [85]	validation_0-rmse:88.32052
# [86]	validation_0-rmse:88.42276
# [87]	validation_0-rmse:88.46811
# [88]	validation_0-rmse:88.83408
# [89]	validation_0-rmse:88.93010
# [90]	validation_0-rmse:89.27915
# [91]	validation_0-rmse:89.35423
# [92]	validation_0-rmse:89.68285
# [93]	validation_0-rmse:89.74988
# [94]	validation_0-rmse:89.81265
# [95]	validation_0-rmse:90.11876
# [96]	validation_0-rmse:90.19471
# [97]	validation_0-rmse:90.49110
# [98]	validation_0-rmse:90.56692
# [99]	validation_0-rmse:90.84617
# [100]	validation_0-rmse:90.90749
# [101]	validation_0-rmse:91.17628
# [102]	validation_0-rmse:91.43863
# [103]	validation_0-rmse:91.50298
# [104]	validation_0-rmse:91.74163
# [105]	validation_0-rmse:91.79607
# [106]	validation_0-rmse:92.04367
# [107]	validation_0-rmse:92.09775
# [108]	validation_0-rmse:92.31302
# [109]	validation_0-rmse:92.52499
# [110]	validation_0-rmse:92.57953
# [111]	validation_0-rmse:92.62528
# [112]	validation_0-rmse:92.67689
# [113]	validation_0-rmse:92.67460
# [114]	validation_0-rmse:92.70359
# [115]	validation_0-rmse:92.75299
# [116]	validation_0-rmse:92.94263
# [117]	validation_0-rmse:93.12010
# [118]	validation_0-rmse:93.13559
# [119]	validation_0-rmse:93.30669
# [120]	validation_0-rmse:93.31091
# [121]	validation_0-rmse:93.32044
# [122]	validation_0-rmse:93.36375
# [123]	validation_0-rmse:93.52620
# [124]	validation_0-rmse:93.68102
# [125]	validation_0-rmse:93.71455
# [126]	validation_0-rmse:93.71541
# [127]	validation_0-rmse:93.73673
# [128]	validation_0-rmse:93.74246
# [129]	validation_0-rmse:93.74803
# [130]	validation_0-rmse:93.78899
# [131]	validation_0-rmse:93.78854
# [132]	validation_0-rmse:93.81735
# [133]	validation_0-rmse:93.85302
# [134]	validation_0-rmse:93.89828
# [135]	validation_0-rmse:93.92572
# [136]	validation_0-rmse:93.93641
# [137]	validation_0-rmse:93.94684
# [138]	validation_0-rmse:93.94676
# [139]	validation_0-rmse:93.97369
# [140]	validation_0-rmse:93.99686
# [141]	validation_0-rmse:94.09969
# [142]	validation_0-rmse:94.10090
# [143]	validation_0-rmse:94.11013
# [144]	validation_0-rmse:94.13325
# [145]	validation_0-rmse:94.16873
# [146]	validation_0-rmse:94.16963
# [147]	validation_0-rmse:94.14929
# [148]	validation_0-rmse:94.15215
# [149]	validation_0-rmse:94.16348
# [150]	validation_0-rmse:94.24461
# [151]	validation_0-rmse:94.24405
# [152]	validation_0-rmse:94.24435
# [153]	validation_0-rmse:94.24718
# [154]	validation_0-rmse:94.24442
# [155]	validation_0-rmse:94.25671
# [156]	validation_0-rmse:94.26672
# [157]	validation_0-rmse:94.29599
# [158]	validation_0-rmse:94.31547
# [159]	validation_0-rmse:94.38056
# [160]	validation_0-rmse:94.38283
# [161]	validation_0-rmse:94.39113
# [162]	validation_0-rmse:94.40220
# [163]	validation_0-rmse:94.42142
# [164]	validation_0-rmse:94.39943
# [165]	validation_0-rmse:94.39937
# [166]	validation_0-rmse:94.45639
# [167]	validation_0-rmse:94.44200
# [168]	validation_0-rmse:94.44260
# [169]	validation_0-rmse:94.45195
# [170]	validation_0-rmse:94.44402
# [171]	validation_0-rmse:94.43479
# [172]	validation_0-rmse:94.43473
# [173]	validation_0-rmse:94.44489
# [174]	validation_0-rmse:94.44330
# [175]	validation_0-rmse:94.44330
# [176]	validation_0-rmse:94.44296
# [177]	validation_0-rmse:94.43421
# [178]	validation_0-rmse:94.41915
# [179]	validation_0-rmse:94.43317
# [180]	validation_0-rmse:94.43296
# [181]	validation_0-rmse:94.43337
# [182]	validation_0-rmse:94.44795
# [183]	validation_0-rmse:94.44606
# [184]	validation_0-rmse:94.44426
# [185]	validation_0-rmse:94.43212
# [186]	validation_0-rmse:94.44640
# [187]	validation_0-rmse:94.44493
# [188]	validation_0-rmse:94.45865
# [189]	validation_0-rmse:94.45855
# [190]	validation_0-rmse:94.45878
# [191]	validation_0-rmse:94.44059
# [192]	validation_0-rmse:94.43963
# [193]	validation_0-rmse:94.43594
# [194]	validation_0-rmse:94.43489
# [195]	validation_0-rmse:94.43458
# [196]	validation_0-rmse:94.44521
# [197]	validation_0-rmse:94.44475
# [198]	validation_0-rmse:94.44802
# [199]	validation_0-rmse:94.47805
# [200]	validation_0-rmse:94.47766
# [201]	validation_0-rmse:94.46730
# [202]	validation_0-rmse:94.46714
# [203]	validation_0-rmse:94.46900
# [204]	validation_0-rmse:94.46865
# [205]	validation_0-rmse:94.46330
# [206]	validation_0-rmse:94.46206
# [207]	validation_0-rmse:94.46214
# [208]	validation_0-rmse:94.49740
# [209]	validation_0-rmse:94.49785
# [210]	validation_0-rmse:94.49744
# [211]	validation_0-rmse:94.48813
# [212]	validation_0-rmse:94.48805
# [213]	validation_0-rmse:94.48777
# [214]	validation_0-rmse:94.48913
# [215]	validation_0-rmse:94.48931
# [216]	validation_0-rmse:94.48903
# [217]	validation_0-rmse:94.49045
# [218]	validation_0-rmse:94.48885
# [219]	validation_0-rmse:94.48959
# [220]	validation_0-rmse:94.49352
# [221]	validation_0-rmse:94.50381
# [222]	validation_0-rmse:94.50363
# [223]	validation_0-rmse:94.50284
# [224]	validation_0-rmse:94.50321
# [225]	validation_0-rmse:94.51748
# [226]	validation_0-rmse:94.51747
# [227]	validation_0-rmse:94.51449
# [228]	validation_0-rmse:94.51484
# [229]	validation_0-rmse:94.51284
# [230]	validation_0-rmse:94.51243
# [231]	validation_0-rmse:94.51207
# [232]	validation_0-rmse:94.50830
# [233]	validation_0-rmse:94.51188
# [234]	validation_0-rmse:94.51288
# [235]	validation_0-rmse:94.51283
# [236]	validation_0-rmse:94.51305
# [237]	validation_0-rmse:94.51514
# [238]	validation_0-rmse:94.51212
# [239]	validation_0-rmse:94.51423
# [240]	validation_0-rmse:94.51328
# [241]	validation_0-rmse:94.51032
# [242]	validation_0-rmse:94.51040
# [243]	validation_0-rmse:94.51050
# [244]	validation_0-rmse:94.52647
# [245]	validation_0-rmse:94.52366
# [246]	validation_0-rmse:94.52292
# [247]	validation_0-rmse:94.52351
# [248]	validation_0-rmse:94.52409
# [249]	validation_0-rmse:94.53054
# [250]	validation_0-rmse:94.54261
# [251]	validation_0-rmse:94.54301
# [252]	validation_0-rmse:94.53259
# [253]	validation_0-rmse:94.53072
# [254]	validation_0-rmse:94.53415
# [255]	validation_0-rmse:94.53410
# [256]	validation_0-rmse:94.53290
# [257]	validation_0-rmse:94.53649
# [258]	validation_0-rmse:94.53580
# [259]	validation_0-rmse:94.54644
# [260]	validation_0-rmse:94.54614
# [261]	validation_0-rmse:94.54983
# [262]	validation_0-rmse:94.57448
# [263]	validation_0-rmse:94.57778
# [264]	validation_0-rmse:94.57677
# [265]	validation_0-rmse:94.58980
# [266]	validation_0-rmse:94.59156
# [267]	validation_0-rmse:94.59463
# [268]	validation_0-rmse:94.61342
# [269]	validation_0-rmse:94.61300
# [270]	validation_0-rmse:94.61565
# [271]	validation_0-rmse:94.61483
# [272]	validation_0-rmse:94.61441
# [273]	validation_0-rmse:94.61357
# [274]	validation_0-rmse:94.61735
# [275]	validation_0-rmse:94.61737
# [276]	validation_0-rmse:94.63853
# [277]	validation_0-rmse:94.63888
# [278]	validation_0-rmse:94.63841
# [279]	validation_0-rmse:94.63881
# [280]	validation_0-rmse:94.65844
# [281]	validation_0-rmse:94.65991
# [282]	validation_0-rmse:94.66172
# [283]	validation_0-rmse:94.66182
# [284]	validation_0-rmse:94.67421
# [285]	validation_0-rmse:94.67033
# [286]	validation_0-rmse:94.66648
# [287]	validation_0-rmse:94.66603
# [288]	validation_0-rmse:94.66540
# [289]	validation_0-rmse:94.66330
# [290]	validation_0-rmse:94.66785
# [291]	validation_0-rmse:94.66850
# [292]	validation_0-rmse:94.66884
# [293]	validation_0-rmse:94.67023
# [294]	validation_0-rmse:94.66994
# [295]	validation_0-rmse:94.67089
# [296]	validation_0-rmse:94.67302
# [297]	validation_0-rmse:94.67405
# [298]	validation_0-rmse:94.67338
# [299]	validation_0-rmse:94.67306
# [300]	validation_0-rmse:94.66557
# [301]	validation_0-rmse:94.66366
# [302]	validation_0-rmse:94.66263
# [303]	validation_0-rmse:94.66185
# [304]	validation_0-rmse:94.66291
# [305]	validation_0-rmse:94.66284
# [306]	validation_0-rmse:94.66247
# [307]	validation_0-rmse:94.66204
# [308]	validation_0-rmse:94.65901
# [309]	validation_0-rmse:94.65508
# [310]	validation_0-rmse:94.65455
# [311]	validation_0-rmse:94.64744
# [312]	validation_0-rmse:94.64649
# [313]	validation_0-rmse:94.64669
# [314]	validation_0-rmse:94.64787
# [315]	validation_0-rmse:94.64643
# [316]	validation_0-rmse:94.64686
# [317]	validation_0-rmse:94.64664
# [318]	validation_0-rmse:94.64586
# [319]	validation_0-rmse:94.64866
# [320]	validation_0-rmse:94.64845
# [321]	validation_0-rmse:94.64839
# [322]	validation_0-rmse:94.65759
# [323]	validation_0-rmse:94.66055
# [324]	validation_0-rmse:94.65814
# [325]	validation_0-rmse:94.66855
# [326]	validation_0-rmse:94.66804
# [327]	validation_0-rmse:94.66778
# [328]	validation_0-rmse:94.66773
# [329]	validation_0-rmse:94.68253
# [330]	validation_0-rmse:94.69100
# [331]	validation_0-rmse:94.69137
# [332]	validation_0-rmse:94.69067
# [333]	validation_0-rmse:94.68955
# [334]	validation_0-rmse:94.70369
# [335]	validation_0-rmse:94.70302
# [336]	validation_0-rmse:94.70270
# [337]	validation_0-rmse:94.70399
# [338]	validation_0-rmse:94.71271
# [339]	validation_0-rmse:94.71522
# [340]	validation_0-rmse:94.71468
# [341]	validation_0-rmse:94.71963
# [342]	validation_0-rmse:94.73113
# [343]	validation_0-rmse:94.73107
# [344]	validation_0-rmse:94.73130
# [345]	validation_0-rmse:94.73667
# [346]	validation_0-rmse:94.73621
# [347]	validation_0-rmse:94.73893
# [348]	validation_0-rmse:94.73899
# [349]	validation_0-rmse:94.73890
# [350]	validation_0-rmse:94.73733
# [351]	validation_0-rmse:94.73415
# [352]	validation_0-rmse:94.72493
# [353]	validation_0-rmse:94.72504
# [354]	validation_0-rmse:94.72504
# [355]	validation_0-rmse:94.72488
# [356]	validation_0-rmse:94.72492
# [357]	validation_0-rmse:94.72417
# [358]	validation_0-rmse:94.72425
# [359]	validation_0-rmse:94.72305
# [360]	validation_0-rmse:94.72373
# [361]	validation_0-rmse:94.72384
# [362]	validation_0-rmse:94.71510
# [363]	validation_0-rmse:94.71750
# [364]	validation_0-rmse:94.71555
# [365]	validation_0-rmse:94.70340
# [366]	validation_0-rmse:94.70393
# [367]	validation_0-rmse:94.70324
# [368]	validation_0-rmse:94.70228
# [369]	validation_0-rmse:94.70383
# [370]	validation_0-rmse:94.70379
# [371]	validation_0-rmse:94.70346
# [372]	validation_0-rmse:94.70316
# [373]	validation_0-rmse:94.70269
# [374]	validation_0-rmse:94.70290
# [375]	validation_0-rmse:94.70338
# [376]	validation_0-rmse:94.70392
# [377]	validation_0-rmse:94.70497
# [378]	validation_0-rmse:94.70800
# [379]	validation_0-rmse:94.70661
# [380]	validation_0-rmse:94.70693
# [381]	validation_0-rmse:94.70734
# [382]	validation_0-rmse:94.70741
# [383]	validation_0-rmse:94.70685
# [384]	validation_0-rmse:94.70634
# [385]	validation_0-rmse:94.70575
# [386]	validation_0-rmse:94.70859
# [387]	validation_0-rmse:94.70881
# [388]	validation_0-rmse:94.70901
# [389]	validation_0-rmse:94.70890
# [390]	validation_0-rmse:94.70840
# [391]	validation_0-rmse:94.71117
# [392]	validation_0-rmse:94.71168
# [393]	validation_0-rmse:94.70088
# [394]	validation_0-rmse:94.70129
# [395]	validation_0-rmse:94.70116
# [396]	validation_0-rmse:94.70116
# [397]	validation_0-rmse:94.70808
# [398]	validation_0-rmse:94.70706
# [399]	validation_0-rmse:94.70320
# [400]	validation_0-rmse:94.70119
# [401]	validation_0-rmse:94.70255
# [402]	validation_0-rmse:94.70235
# [403]	validation_0-rmse:94.70345
# [404]	validation_0-rmse:94.70323
# [405]	validation_0-rmse:94.70331
# [406]	validation_0-rmse:94.70342
# [407]	validation_0-rmse:94.70508
# [408]	validation_0-rmse:94.70508
# [409]	validation_0-rmse:94.70530
# [410]	validation_0-rmse:94.70519
# [411]	validation_0-rmse:94.70443
# [412]	validation_0-rmse:94.70290
# [413]	validation_0-rmse:94.70210
# [414]	validation_0-rmse:94.70312
# [415]	validation_0-rmse:94.70296
# [416]	validation_0-rmse:94.70189
# [417]	validation_0-rmse:94.70210
# [418]	validation_0-rmse:94.69995
# [419]	validation_0-rmse:94.69998
# [420]	validation_0-rmse:94.70016
# [421]	validation_0-rmse:94.69877
# [422]	validation_0-rmse:94.69873
# [423]	validation_0-rmse:94.70031
# [424]	validation_0-rmse:94.70026
# [425]	validation_0-rmse:94.69894
# [426]	validation_0-rmse:94.69869
# [427]	validation_0-rmse:94.69867
# [428]	validation_0-rmse:94.70018
# [429]	validation_0-rmse:94.69943
# [430]	validation_0-rmse:94.69961
# [431]	validation_0-rmse:94.69966
# [432]	validation_0-rmse:94.69968
# [433]	validation_0-rmse:94.69918
# [434]	validation_0-rmse:94.69253
# [435]	validation_0-rmse:94.69276
# [436]	validation_0-rmse:94.69266
# [437]	validation_0-rmse:94.69269
# [438]	validation_0-rmse:94.69149
# [439]	validation_0-rmse:94.69108
# [440]	validation_0-rmse:94.69103
# [441]	validation_0-rmse:94.69188
# [442]	validation_0-rmse:94.69178
# [443]	validation_0-rmse:94.69204
# [444]	validation_0-rmse:94.69246
# [445]	validation_0-rmse:94.68420
# [446]	validation_0-rmse:94.68465
# [447]	validation_0-rmse:94.68471
# [448]	validation_0-rmse:94.68513
# [449]	validation_0-rmse:94.68498
# [450]	validation_0-rmse:94.68593
# [451]	validation_0-rmse:94.68588
# [452]	validation_0-rmse:94.68597
# [453]	validation_0-rmse:94.68610
# [454]	validation_0-rmse:94.68509
# [455]	validation_0-rmse:94.68393
# [456]	validation_0-rmse:94.68444
# [457]	validation_0-rmse:94.68585
# [458]	validation_0-rmse:94.68659
# [459]	validation_0-rmse:94.67563
# [460]	validation_0-rmse:94.67562
# [461]	validation_0-rmse:94.67527
# [462]	validation_0-rmse:94.67333
# [463]	validation_0-rmse:94.67307
# [464]	validation_0-rmse:94.67405
# [465]	validation_0-rmse:94.67425
# [466]	validation_0-rmse:94.67445
# [467]	validation_0-rmse:94.67732
# [468]	validation_0-rmse:94.67733
# [469]	validation_0-rmse:94.67715
# [470]	validation_0-rmse:94.67678
# [471]	validation_0-rmse:94.67743
# [472]	validation_0-rmse:94.67707
# [473]	validation_0-rmse:94.68113
# [474]	validation_0-rmse:94.68161
# [475]	validation_0-rmse:94.68213
# [476]	validation_0-rmse:94.68210
# [477]	validation_0-rmse:94.68201
# [478]	validation_0-rmse:94.68346
# [479]	validation_0-rmse:94.68148
# [480]	validation_0-rmse:94.68140
# [481]	validation_0-rmse:94.68148
# [482]	validation_0-rmse:94.68227
# [483]	validation_0-rmse:94.68191
# [484]	validation_0-rmse:94.68179
# [485]	validation_0-rmse:94.68249
# [486]	validation_0-rmse:94.68292
# [487]	validation_0-rmse:94.68265
# [488]	validation_0-rmse:94.68305
# [489]	validation_0-rmse:94.68307
# [490]	validation_0-rmse:94.68278
# [491]	validation_0-rmse:94.69053
# [492]	validation_0-rmse:94.68824
# [493]	validation_0-rmse:94.68853
# [494]	validation_0-rmse:94.68794
# [495]	validation_0-rmse:94.68729
# [496]	validation_0-rmse:94.68880
# [497]	validation_0-rmse:94.68663
# [498]	validation_0-rmse:94.68533
# [499]	validation_0-rmse:94.68942
# [500]	validation_0-rmse:94.69057
# [501]	validation_0-rmse:94.69120
# [502]	validation_0-rmse:94.69114
# [503]	validation_0-rmse:94.69186
# [504]	validation_0-rmse:94.69170
# [505]	validation_0-rmse:94.69160
# [506]	validation_0-rmse:94.69523
# [507]	validation_0-rmse:94.69339
# [508]	validation_0-rmse:94.69344
# [509]	validation_0-rmse:94.69302
# [510]	validation_0-rmse:94.69349
# [511]	validation_0-rmse:94.69324
# [512]	validation_0-rmse:94.70075
# [513]	validation_0-rmse:94.70217
# [514]	validation_0-rmse:94.70198
# [515]	validation_0-rmse:94.70255
# [516]	validation_0-rmse:94.70120
# [517]	validation_0-rmse:94.69896
# [518]	validation_0-rmse:94.69898
# [519]	validation_0-rmse:94.69794
# [520]	validation_0-rmse:94.69755
# [521]	validation_0-rmse:94.69902
# [522]	validation_0-rmse:94.69908
# [523]	validation_0-rmse:94.69919
# [524]	validation_0-rmse:94.69869
# [525]	validation_0-rmse:94.69493
# [526]	validation_0-rmse:94.69156
# [527]	validation_0-rmse:94.69137
# [528]	validation_0-rmse:94.69134
# [529]	validation_0-rmse:94.69098
# [530]	validation_0-rmse:94.69106
# [531]	validation_0-rmse:94.69008
# [532]	validation_0-rmse:94.68724
# [533]	validation_0-rmse:94.68819
# [534]	validation_0-rmse:94.68659
# [535]	validation_0-rmse:94.68644
# [536]	validation_0-rmse:94.68701
# [537]	validation_0-rmse:94.68853
# [538]	validation_0-rmse:94.68760
# [539]	validation_0-rmse:94.68651
# [540]	validation_0-rmse:94.68693
# [541]	validation_0-rmse:94.68650
# [542]	validation_0-rmse:94.68682
# [543]	validation_0-rmse:94.68599
# [544]	validation_0-rmse:94.68583
# [545]	validation_0-rmse:94.68413
# [546]	validation_0-rmse:94.68371
# [547]	validation_0-rmse:94.68431
# [548]	validation_0-rmse:94.68370
# [549]	validation_0-rmse:94.68329
# [550]	validation_0-rmse:94.68321
# [551]	validation_0-rmse:94.68304
# [552]	validation_0-rmse:94.68275
# [553]	validation_0-rmse:94.68234
# [554]	validation_0-rmse:94.68223
# [555]	validation_0-rmse:94.68190
# [556]	validation_0-rmse:94.68091
# [557]	validation_0-rmse:94.68074
# [558]	validation_0-rmse:94.68243
# [559]	validation_0-rmse:94.68355
# [560]	validation_0-rmse:94.68303
# [561]	validation_0-rmse:94.68192
# [562]	validation_0-rmse:94.68188
# [563]	validation_0-rmse:94.67783
# [564]	validation_0-rmse:94.67839
# [565]	validation_0-rmse:94.67756
# [566]	validation_0-rmse:94.67802
# [567]	validation_0-rmse:94.67799
# [568]	validation_0-rmse:94.67810
# [569]	validation_0-rmse:94.67755
# [570]	validation_0-rmse:94.67722
# [571]	validation_0-rmse:94.67648
# [572]	validation_0-rmse:94.67476
# [573]	validation_0-rmse:94.67475
# [574]	validation_0-rmse:94.67553
# [575]	validation_0-rmse:94.67481
# [576]	validation_0-rmse:94.67406
# [577]	validation_0-rmse:94.67325
# [578]	validation_0-rmse:94.67319
# [579]	validation_0-rmse:94.67318
# [580]	validation_0-rmse:94.67321
# [581]	validation_0-rmse:94.67252
# [582]	validation_0-rmse:94.67242
# [583]	validation_0-rmse:94.67238
# [584]	validation_0-rmse:94.67239
# [585]	validation_0-rmse:94.67269
# [586]	validation_0-rmse:94.67263
# [587]	validation_0-rmse:94.66743
# [588]	validation_0-rmse:94.66843
# [589]	validation_0-rmse:94.66846
# [590]	validation_0-rmse:94.66836
# [591]	validation_0-rmse:94.66880
# [592]	validation_0-rmse:94.66841
# [593]	validation_0-rmse:94.66895
# [594]	validation_0-rmse:94.67021
# [595]	validation_0-rmse:94.67033
# [596]	validation_0-rmse:94.67027
# [597]	validation_0-rmse:94.67039
# [598]	validation_0-rmse:94.66994
# [599]	validation_0-rmse:94.66879
# [600]	validation_0-rmse:94.66872
# [601]	validation_0-rmse:94.66860
# [602]	validation_0-rmse:94.66861
# [603]	validation_0-rmse:94.66859
# [604]	validation_0-rmse:94.66834
# [605]	validation_0-rmse:94.66872
# [606]	validation_0-rmse:94.66909
# [607]	validation_0-rmse:94.66570
# [608]	validation_0-rmse:94.66501
# [609]	validation_0-rmse:94.66539
# [610]	validation_0-rmse:94.66539
# [611]	validation_0-rmse:94.66490
# [612]	validation_0-rmse:94.66328
# [613]	validation_0-rmse:94.66320
# [614]	validation_0-rmse:94.66327
# [615]	validation_0-rmse:94.66313
# [616]	validation_0-rmse:94.66294
# [617]	validation_0-rmse:94.66302
# [618]	validation_0-rmse:94.66313
# [619]	validation_0-rmse:94.66299
# [620]	validation_0-rmse:94.66200
# [621]	validation_0-rmse:94.66161
# [622]	validation_0-rmse:94.66101
# [623]	validation_0-rmse:94.66093
# [624]	validation_0-rmse:94.65938
# [625]	validation_0-rmse:94.65933
# [626]	validation_0-rmse:94.65849
# [627]	validation_0-rmse:94.65862
# [628]	validation_0-rmse:94.65912
# [629]	validation_0-rmse:94.65858
# [630]	validation_0-rmse:94.65856
# [631]	validation_0-rmse:94.65967
# [632]	validation_0-rmse:94.65979
# [633]	validation_0-rmse:94.65987
# [634]	validation_0-rmse:94.65962
# [635]	validation_0-rmse:94.65878
# [636]	validation_0-rmse:94.65895
# [637]	validation_0-rmse:94.65904
# [638]	validation_0-rmse:94.65833
# [639]	validation_0-rmse:94.65834
# [640]	validation_0-rmse:94.65843
# [641]	validation_0-rmse:94.65690
# [642]	validation_0-rmse:94.65663
# [643]	validation_0-rmse:94.65677
# [644]	validation_0-rmse:94.65733
# [645]	validation_0-rmse:94.65717
# [646]	validation_0-rmse:94.66459
# [647]	validation_0-rmse:94.66630
# [648]	validation_0-rmse:94.66685
# [649]	validation_0-rmse:94.66680
# [650]	validation_0-rmse:94.66453
# [651]	validation_0-rmse:94.66619
# [652]	validation_0-rmse:94.66564
# [653]	validation_0-rmse:94.66548
# [654]	validation_0-rmse:94.66528
# [655]	validation_0-rmse:94.66525
# [656]	validation_0-rmse:94.66573
# [657]	validation_0-rmse:94.66539
# [658]	validation_0-rmse:94.66535
# [659]	validation_0-rmse:94.66543
# [660]	validation_0-rmse:94.66543
# [661]	validation_0-rmse:94.66540
# [662]	validation_0-rmse:94.66601
# [663]	validation_0-rmse:94.66659
# [664]	validation_0-rmse:94.66557
# [665]	validation_0-rmse:94.66389
# [666]	validation_0-rmse:94.66364
# [667]	validation_0-rmse:94.66369
# [668]	validation_0-rmse:94.66368
# [669]	validation_0-rmse:94.66377
# [670]	validation_0-rmse:94.66385
# [671]	validation_0-rmse:94.66396
# [672]	validation_0-rmse:94.66408
# [673]	validation_0-rmse:94.66433
# [674]	validation_0-rmse:94.66410
# [675]	validation_0-rmse:94.66539
# [676]	validation_0-rmse:94.66724
# [677]	validation_0-rmse:94.66707
# [678]	validation_0-rmse:94.66873
# [679]	validation_0-rmse:94.66837
# [680]	validation_0-rmse:94.66816
# [681]	validation_0-rmse:94.66975
# [682]	validation_0-rmse:94.67120
# [683]	validation_0-rmse:94.67072
# [684]	validation_0-rmse:94.67104
# [685]	validation_0-rmse:94.67105
# [686]	validation_0-rmse:94.67368
# [687]	validation_0-rmse:94.67381
# [688]	validation_0-rmse:94.67358
# [689]	validation_0-rmse:94.67365
# [690]	validation_0-rmse:94.67363
# [691]	validation_0-rmse:94.67356
# [692]	validation_0-rmse:94.67149
# [693]	validation_0-rmse:94.67099
# [694]	validation_0-rmse:94.67114
# [695]	validation_0-rmse:94.67270
# [696]	validation_0-rmse:94.67262
# [697]	validation_0-rmse:94.67270
# [698]	validation_0-rmse:94.67392
# [699]	validation_0-rmse:94.67384
# [700]	validation_0-rmse:94.67358
# [701]	validation_0-rmse:94.67345
# [702]	validation_0-rmse:94.67363
# [703]	validation_0-rmse:94.67364
# [704]	validation_0-rmse:94.67200
# [705]	validation_0-rmse:94.67171
# [706]	validation_0-rmse:94.67158
# [707]	validation_0-rmse:94.67121
# [708]	validation_0-rmse:94.67103
# [709]	validation_0-rmse:94.67082
# [710]	validation_0-rmse:94.67133
# [711]	validation_0-rmse:94.67137
# [712]	validation_0-rmse:94.67010
# [713]	validation_0-rmse:94.66997
# [714]	validation_0-rmse:94.66996
# [715]	validation_0-rmse:94.66998
# [716]	validation_0-rmse:94.67753
# [717]	validation_0-rmse:94.67646
# [718]	validation_0-rmse:94.67629
# [719]	validation_0-rmse:94.67657
# [720]	validation_0-rmse:94.67631
# [721]	validation_0-rmse:94.67612
# [722]	validation_0-rmse:94.67586
# [723]	validation_0-rmse:94.67585
# [724]	validation_0-rmse:94.67565
# [725]	validation_0-rmse:94.67570
# [726]	validation_0-rmse:94.67437
# [727]	validation_0-rmse:94.67522
# [728]	validation_0-rmse:94.67515
# [729]	validation_0-rmse:94.67525
# [730]	validation_0-rmse:94.67529
# [731]	validation_0-rmse:94.67519
# [732]	validation_0-rmse:94.67501
# [733]	validation_0-rmse:94.67579
# [734]	validation_0-rmse:94.67580
# [735]	validation_0-rmse:94.67589
# [736]	validation_0-rmse:94.67615
# [737]	validation_0-rmse:94.67644
# [738]	validation_0-rmse:94.67635
# [739]	validation_0-rmse:94.67638
# [740]	validation_0-rmse:94.67645
# [741]	validation_0-rmse:94.68018
# [742]	validation_0-rmse:94.67943
# [743]	validation_0-rmse:94.68058
# [744]	validation_0-rmse:94.68142
# [745]	validation_0-rmse:94.68405
# [746]	validation_0-rmse:94.68340
# [747]	validation_0-rmse:94.68316
# [748]	validation_0-rmse:94.68314
# [749]	validation_0-rmse:94.68302
# [750]	validation_0-rmse:94.68298
# [751]	validation_0-rmse:94.68271
# [752]	validation_0-rmse:94.68207
# [753]	validation_0-rmse:94.68216
# [754]	validation_0-rmse:94.68215
# [755]	validation_0-rmse:94.68419
# [756]	validation_0-rmse:94.68372
# [757]	validation_0-rmse:94.68356
# [758]	validation_0-rmse:94.68384
# [759]	validation_0-rmse:94.68376
# [760]	validation_0-rmse:94.68155
# [761]	validation_0-rmse:94.68182
# [762]	validation_0-rmse:94.68187
# [763]	validation_0-rmse:94.68282
# [764]	validation_0-rmse:94.68275
# [765]	validation_0-rmse:94.68293
# [766]	validation_0-rmse:94.68287
# [767]	validation_0-rmse:94.68290
# [768]	validation_0-rmse:94.68359
# [769]	validation_0-rmse:94.68341
# [770]	validation_0-rmse:94.68325
# [771]	validation_0-rmse:94.68330
# [772]	validation_0-rmse:94.68309
# [773]	validation_0-rmse:94.68328
# [774]	validation_0-rmse:94.68303
# [775]	validation_0-rmse:94.68286
# [776]	validation_0-rmse:94.68305
# [777]	validation_0-rmse:94.68298
# [778]	validation_0-rmse:94.68280
# [779]	validation_0-rmse:94.68258
# [780]	validation_0-rmse:94.68250
# [781]	validation_0-rmse:94.68239
# [782]	validation_0-rmse:94.68210
# [783]	validation_0-rmse:94.68213
# [784]	validation_0-rmse:94.68227
# [785]	validation_0-rmse:94.68236
# [786]	validation_0-rmse:94.68224
# [787]	validation_0-rmse:94.68216
# [788]	validation_0-rmse:94.68226
# [789]	validation_0-rmse:94.68225
# [790]	validation_0-rmse:94.68213
# [791]	validation_0-rmse:94.68207
# [792]	validation_0-rmse:94.68160
# [793]	validation_0-rmse:94.68207
# [794]	validation_0-rmse:94.68206
# [795]	validation_0-rmse:94.68200
# [796]	validation_0-rmse:94.68203
# [797]	validation_0-rmse:94.68212
# [798]	validation_0-rmse:94.68241
# [799]	validation_0-rmse:94.68243
# [800]	validation_0-rmse:94.68236
# [801]	validation_0-rmse:94.68250
# [802]	validation_0-rmse:94.68284
# [803]	validation_0-rmse:94.68281
# [804]	validation_0-rmse:94.68275
# [805]	validation_0-rmse:94.68298
# [806]	validation_0-rmse:94.68289
# [807]	validation_0-rmse:94.68282
# [808]	validation_0-rmse:94.68284
# [809]	validation_0-rmse:94.68295
# [810]	validation_0-rmse:94.68323
# [811]	validation_0-rmse:94.68310
# [812]	validation_0-rmse:94.68350
# [813]	validation_0-rmse:94.68368
# [814]	validation_0-rmse:94.68366
# [815]	validation_0-rmse:94.68357
# [816]	validation_0-rmse:94.68358
# [817]	validation_0-rmse:94.68239
# [818]	validation_0-rmse:94.68186
# [819]	validation_0-rmse:94.68225
# [820]	validation_0-rmse:94.68274
# [821]	validation_0-rmse:94.68271
# [822]	validation_0-rmse:94.68276
# [823]	validation_0-rmse:94.67997
# [824]	validation_0-rmse:94.67999
# [825]	validation_0-rmse:94.67991
# [826]	validation_0-rmse:94.68000
# [827]	validation_0-rmse:94.67999
# [828]	validation_0-rmse:94.68034
# [829]	validation_0-rmse:94.68043
# [830]	validation_0-rmse:94.67991
# [831]	validation_0-rmse:94.68025
# [832]	validation_0-rmse:94.68033
# [833]	validation_0-rmse:94.68007
# [834]	validation_0-rmse:94.67929
# [835]	validation_0-rmse:94.67958
# [836]	validation_0-rmse:94.67954
# [837]	validation_0-rmse:94.67964
# [838]	validation_0-rmse:94.67966
# [839]	validation_0-rmse:94.67986
# [840]	validation_0-rmse:94.67915
# [841]	validation_0-rmse:94.68010
# [842]	validation_0-rmse:94.68007
# [843]	validation_0-rmse:94.68012
# [844]	validation_0-rmse:94.68023
# [845]	validation_0-rmse:94.67952
# [846]	validation_0-rmse:94.67965
# [847]	validation_0-rmse:94.67960
# [848]	validation_0-rmse:94.68563
# [849]	validation_0-rmse:94.68553
# [850]	validation_0-rmse:94.68549
# [851]	validation_0-rmse:94.68373
# [852]	validation_0-rmse:94.68361
# [853]	validation_0-rmse:94.68364
# [854]	validation_0-rmse:94.68353
# [855]	validation_0-rmse:94.68342
# [856]	validation_0-rmse:94.68336
# [857]	validation_0-rmse:94.68367
# [858]	validation_0-rmse:94.68279
# [859]	validation_0-rmse:94.68295
# [860]	validation_0-rmse:94.68293
# [861]	validation_0-rmse:94.68298
# [862]	validation_0-rmse:94.68299
# [863]	validation_0-rmse:94.68302
# [864]	validation_0-rmse:94.68242
# [865]	validation_0-rmse:94.68246
# [866]	validation_0-rmse:94.68238
# [867]	validation_0-rmse:94.68240
# [868]	validation_0-rmse:94.68139
# [869]	validation_0-rmse:94.68140
# [870]	validation_0-rmse:94.68142
# [871]	validation_0-rmse:94.68079
# [872]	validation_0-rmse:94.68078
# [873]	validation_0-rmse:94.68030
# [874]	validation_0-rmse:94.67869
# [875]	validation_0-rmse:94.67930
# [876]	validation_0-rmse:94.67941
# [877]	validation_0-rmse:94.67966
# [878]	validation_0-rmse:94.67956
# [879]	validation_0-rmse:94.67949
# [880]	validation_0-rmse:94.67938
# [881]	validation_0-rmse:94.67940
# [882]	validation_0-rmse:94.67934
# [883]	validation_0-rmse:94.67937
# [884]	validation_0-rmse:94.67833
# [885]	validation_0-rmse:94.67824
# [886]	validation_0-rmse:94.67807
# [887]	validation_0-rmse:94.67791
# [888]	validation_0-rmse:94.67758
# [889]	validation_0-rmse:94.67760
# [890]	validation_0-rmse:94.67759
# [891]	validation_0-rmse:94.67739
# [892]	validation_0-rmse:94.67736
# [893]	validation_0-rmse:94.67681
# [894]	validation_0-rmse:94.67459
# [895]	validation_0-rmse:94.67461
# [896]	validation_0-rmse:94.67444
# [897]	validation_0-rmse:94.67430
# [898]	validation_0-rmse:94.67403
# [899]	validation_0-rmse:94.67190
# [900]	validation_0-rmse:94.67187
# [901]	validation_0-rmse:94.67006
# [902]	validation_0-rmse:94.66999
# [903]	validation_0-rmse:94.66828
# [904]	validation_0-rmse:94.66812
# [905]	validation_0-rmse:94.66691
# [906]	validation_0-rmse:94.66613
# [907]	validation_0-rmse:94.66613
# [908]	validation_0-rmse:94.66624
# [909]	validation_0-rmse:94.66621
# [910]	validation_0-rmse:94.66627
# [911]	validation_0-rmse:94.66632
# [912]	validation_0-rmse:94.66610
# [913]	validation_0-rmse:94.66443
# [914]	validation_0-rmse:94.66436
# [915]	validation_0-rmse:94.66379
# [916]	validation_0-rmse:94.66221
# [917]	validation_0-rmse:94.66207
# [918]	validation_0-rmse:94.66067
# [919]	validation_0-rmse:94.66067
# [920]	validation_0-rmse:94.65924
# [921]	validation_0-rmse:94.65932
# [922]	validation_0-rmse:94.65968
# [923]	validation_0-rmse:94.65973
# [924]	validation_0-rmse:94.66058
# [925]	validation_0-rmse:94.66063
# [926]	validation_0-rmse:94.66144
# [927]	validation_0-rmse:94.66139
# [928]	validation_0-rmse:94.66143
# [929]	validation_0-rmse:94.66105
# [930]	validation_0-rmse:94.66190
# [931]	validation_0-rmse:94.66189
# [932]	validation_0-rmse:94.66139
# [933]	validation_0-rmse:94.66119
# [934]	validation_0-rmse:94.66120
# [935]	validation_0-rmse:94.66115
# [936]	validation_0-rmse:94.66107
# [937]	validation_0-rmse:94.66134
# [938]	validation_0-rmse:94.66133
# [939]	validation_0-rmse:94.66146
# [940]	validation_0-rmse:94.66150
# [941]	validation_0-rmse:94.66065
# [942]	validation_0-rmse:94.66058
# [943]	validation_0-rmse:94.66027
# [944]	validation_0-rmse:94.65986
# [945]	validation_0-rmse:94.65950
# [946]	validation_0-rmse:94.65952
# [947]	validation_0-rmse:94.65965
# [948]	validation_0-rmse:94.66059
# [949]	validation_0-rmse:94.66002
# [950]	validation_0-rmse:94.65999
# [951]	validation_0-rmse:94.65993
# [952]	validation_0-rmse:94.65975
# [953]	validation_0-rmse:94.65867
# [954]	validation_0-rmse:94.65873
# [955]	validation_0-rmse:94.65863
# [956]	validation_0-rmse:94.65858
# [957]	validation_0-rmse:94.65761
# [958]	validation_0-rmse:94.65719
# [959]	validation_0-rmse:94.65717
# [960]	validation_0-rmse:94.65713
# [961]	validation_0-rmse:94.65710
# [962]	validation_0-rmse:94.65654
# [963]	validation_0-rmse:94.65660
# [964]	validation_0-rmse:94.65661
# [965]	validation_0-rmse:94.65661
# [966]	validation_0-rmse:94.65660
# [967]	validation_0-rmse:94.65663
# [968]	validation_0-rmse:94.65663
# [969]	validation_0-rmse:94.65664
# [970]	validation_0-rmse:94.65617
# [971]	validation_0-rmse:94.65621
# [972]	validation_0-rmse:94.65615
# [973]	validation_0-rmse:94.65598
# [974]	validation_0-rmse:94.65732
# [975]	validation_0-rmse:94.65753
# [976]	validation_0-rmse:94.65781
# [977]	validation_0-rmse:94.65886
# [978]	validation_0-rmse:94.65816
# [979]	validation_0-rmse:94.65806
# [980]	validation_0-rmse:94.65795
# [981]	validation_0-rmse:94.65782
# [982]	validation_0-rmse:94.65783
# [983]	validation_0-rmse:94.65785
# [984]	validation_0-rmse:94.65784
# [985]	validation_0-rmse:94.65709
# [986]	validation_0-rmse:94.65662
# [987]	validation_0-rmse:94.65657
# [988]	validation_0-rmse:94.65655
# [989]	validation_0-rmse:94.65680
# [990]	validation_0-rmse:94.65679
# [991]	validation_0-rmse:94.65648
# [992]	validation_0-rmse:94.65652
# [993]	validation_0-rmse:94.65652
# [994]	validation_0-rmse:94.65653
# [995]	validation_0-rmse:94.65652
# [996]	validation_0-rmse:94.65647
# [997]	validation_0-rmse:94.65646
# [998]	validation_0-rmse:94.65636
# [999]	validation_0-rmse:94.65652
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=1000,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
xg_pred = x_model.predict(fit_test)
print(f"XGBoost R2 Score: {r2_score(score_test, xg_pred)}")
print(f"MAE of XGBoost: {mean_absolute_error(score_test, xg_pred)}")
print(f"MSE of XGBoost: {mean_squared_error(score_test, xg_pred)}")

# Print highest predicted battery score for xgboost
best_xgboost_score = np.max(xg_pred)
best_xgboost_index = np.argmax(xg_pred)
print("Best XGBoost Predicted Battery Score:", best_xgboost_score)
print("Best XGBoost Predicted Battery Material:", pdata.iloc[best_xgboost_index, 0])
# Out:
# XGBoost R2 Score: 0.9008787443155742
# MAE of XGBoost: 10.436018462354395
# MSE of XGBoost: 8959.856394899487
# Best XGBoost Predicted Battery Score: 4071.6873
# Best XGBoost Predicted Battery Material: Ca0-1Mo2O5

# %% [markdown]
# ## Testing on other DFT-based features from materials project:
# Testing to see if our model & scoring function can predict the quality of a battery based on untrained features, which still correlate with battery lifetime and hence the score.
# #### Importing and preprocessing test data similar to how we processed training data:

# %%
test_data = test_data.dropna()
test_data = test_data.reset_index(drop=True)

# %%
structures = test_data["structure"]
structure_dict_test = ast.literal_eval(structures[1])
structure_test = Structure.from_dict(structure_dict_test)

# %%
structure_abc = test_data["structure"].apply(get_abc) # abc values in Angstrom
structure_abc_df = pd.DataFrame(structure_abc.tolist(), columns=['a', 'b', 'c'])
test_data = test_data.drop(columns=["structure"], axis=1)
test_data = pd.concat([test_data, structure_abc_df], axis=1)
test_data = test_data.dropna()
test_data = test_data.reset_index(drop=True)

# %%
# Reformatting the test dataset to conform to train data
stability_discharge = test_data["energy_above_hull"]
material_density = test_data["density"]
formation_energy_per_atom = test_data["formation_energy_per_atom"]
band_gap = test_data["band_gap"]
a = test_data["a"]
b = test_data["b"]
c = test_data["c"]
capacity_grav = test_data["capacity_grav"]
energy_grav = test_data["energy_grav"]
formula_pretty = test_data["formula_pretty"]
max_delta_volume = test_data["max_delta_volume"]
voltage = test_data["average_voltage"]
test_data_short = pd.DataFrame({
    "formula_pretty": formula_pretty,
    "max_delta_volume": max_delta_volume,
    "average_voltage": np.abs(voltage),
    "capacity_grav": capacity_grav,
    "stability_discharge": stability_discharge,
    "material_density": material_density,
    "formation_energy_per_atom": formation_energy_per_atom,
    "band_gap": band_gap,
    "a": a,
    "b": b,
    "c": c,
})

# %%
test_data_short.head()
# Out:
#   formula_pretty  max_delta_volume  average_voltage  capacity_grav  \
# 0          CsMg3          0.360047         0.175966     781.306652
# 1          CsRb3          2.388242         0.019232     206.531251
# 2           CsK3          1.907409         0.032541     321.360236
# 3            CsY          0.187048         0.465008     362.490310
# 4          CsRb3          2.403271         0.043412     206.531251
#
#    stability_discharge  material_density  formation_energy_per_atom  band_gap  \
# 0             0.276177          2.203340                   0.276177       0.0
# 1             0.027286          1.600529                   0.027286       0.0
# 2             0.018994          1.192071                   0.018994       0.0
# 3             0.716882          3.833530                   0.716882       0.0
# 4             0.045421          1.590429                   0.045421       0.0
#
#           a         b         c
# 0  3.752604  4.900757  8.434517
# 1  7.391966  7.391966  7.391965
# 2  8.635094  8.635094  8.635094
# 3  3.843415  3.843415  7.510495
# 4  9.078593  9.078593  9.078593

# %%
test_data_feature = test_data_short.drop(columns=["formula_pretty"])
test_data_score = energy_grav
norm_test_data = pd.DataFrame(
    StandardScaler().fit_transform(test_data_feature),
    columns=test_data_feature.columns
)

# %% [markdown]
# ### Using our testing data to predict GED using XGBoost, Ridge, and ElasticNet
# Also printing out the $R^2$ score for each model

# %%
xg_pred = x_model.predict(test_data_feature)
print(f"XGBoost R2 Score: {r2_score(np.abs(test_data_score), xg_pred)}")
xb_f_weight = x_model.feature_importances_
print(f"MAE of XGBoost: {mean_absolute_error(test_data_score, xg_pred)}")
print(f"MSE of XGBoost: {mean_squared_error(test_data_score, xg_pred)}")
# Out:
# XGBoost R2 Score: 0.7547105151293501
# MAE of XGBoost: 158.6891163855027
# MSE of XGBoost: 447389.190260381

# %%
test_pred_ridge = ridge_pipeline.predict(test_data_feature)
print(f"Ridge R2 Score: {r2_score(np.abs(test_data_score), test_pred_ridge)}")
ridge_f_weight = ridge_pipeline.named_steps["ridge"].coef_
print(f"MAE of Ridge: {mean_absolute_error(test_data_score, test_pred_ridge)}")
print(f"MSE of Ridge: {mean_squared_error(test_data_score, test_pred_ridge)}")
# Out:
# Ridge R2 Score: -0.8574107614184205
# MAE of Ridge: 427.619845187351
# MSE of Ridge: 645813.6737151331

# %%
test_pred_enet = enet_pipeline.predict(test_data_feature)
print(f"Elastic Net R2 Score: {r2_score(np.abs(test_data_score), test_pred_enet)}")
enet_f_weight = enet_pipeline.named_steps["enet"].coef_
print(f"MAE of Elastic Net: {mean_absolute_error(test_data_score, test_pred_enet)}")
print(f"MSE of Elastic Net: {mean_squared_error(test_data_score, test_pred_enet)}")
# Out:
# Elastic Net R2 Score: 0.10457235694708689
# MAE of Elastic Net: 363.0118139865436
# MSE of Elastic Net: 338592.59580333985

# %% [markdown]
# ### Comparing the GED predictions from Ridge, ElasticNet, and XGBoost relative to the true value.

# %%
random_mats = energy_grav.sample(n=10, random_state=42).values.flatten()
random_index = [energy_grav[energy_grav == val].index[0] for val in random_mats]

# %%
# Get material names for the randomly selected materials
random_materials = test_data_short.loc[random_index, "formula_pretty"].values
plt.figure(figsize=(10, 6))
plt.scatter(random_materials, test_pred_enet[random_index], marker='x', label='Elastic Net Predicted Score')
plt.scatter(random_materials, test_pred_ridge[random_index], marker='x', label='Ridge Predicted Score')
plt.scatter(random_materials, xg_pred[random_index], marker='x', label='XG-Boost Predicted Score')
plt.scatter(random_materials, np.abs(random_mats), marker='o', label='Test data GED values') # plotting the magnitude of GED as that is what our model predicts
plt.xlabel('Random material')
plt.ylabel(r'Energy Grav $(W⋅h/kg)$')
plt.legend()
plt.title('Comparing Predicted Scores for Randomly Selected Materials from our three models to the actual GED value')
# Out:
# Text(0.5, 1.0, 'Comparing Predicted Scores for Randomly Selected Materials from our three models to the actual GED value')

# %%
# Print residuals for the randomly selected materials
residuals_enet = test_pred_enet[random_index] - random_mats
residuals_ridge = test_pred_ridge[random_index] - random_mats
residuals_xgboost = xg_pred[random_index] - random_mats
print("Elastic Net Residuals:", residuals_enet)
print("Ridge Residuals:", residuals_ridge)
print("XGBoost Residuals:", residuals_xgboost)
# Out:
# Elastic Net Residuals: [ 830.12287864 -245.35974131  434.84557728  460.65406963  645.55368188
#    99.76693389  397.09873363   46.1987001    -5.63591969  290.04238759]
# Ridge Residuals: [1194.50475661 -393.95013643  278.01343952  494.7516422   573.23211278
#    74.95032706  723.62063669  -39.86321417   -9.49412023  549.24031421]
# XGBoost Residuals: [652.1333501   15.91459099 306.26712279 170.62948398 589.58902945
#    3.42471627 -10.21339979   7.6365922    3.06998743  -5.67885513]

# %%
# Plot the feature importance for the XGBoost model against feature weights for ridge and elastic net with feature names for comparison
feature_names = [r"Max $\Delta$ Volume", r"Mean Voltage", r"Capacity Grav", r"Stab Discharge", r"Material Density", r"Formation Energy", r"Band Gap", r"a", r"b", r"c"]
plt.figure(figsize=(16, 6))
plt.scatter(feature_names, xb_f_weight, alpha=1, label='XGBoost Coefficients')
plt.scatter(feature_names, ridge_f_weight, alpha=1, label='Ridge Coefficients')
plt.scatter(feature_names, enet_f_weight, alpha=1, label='Elastic Net Coefficients')
# plt.xticks(rotation=15)
plt.ylabel('Feature Weight')
plt.title('Feature Importance for XGBoost vs Coefficients for Ridge and Elastic Net')
plt.legend()
